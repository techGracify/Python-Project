# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Importing a CSV file into Pandas for data analytics

d = pd.read_csv(r'C:\Users\USER\Desktop/Employe_Performance_dataset.csv')

# Convert to Dataframe
df=pd.DataFrame(d)

df
# Out:
#        ID                Name  Age  Gender Department  Salary Joining Date  \
# 0       1        Cory Escobar   48  Female         HR    5641     5/3/2015
# 1       2     Timothy Sanchez   25   Other      Sales    4249    11/9/2020
# 2       3        Chad Nichols   57   Other      Sales    3058    2/12/2019
# 3       4  Christine Williams   58  Female         IT    5895     9/8/2017
# 4       5        Amber Harris   35   Other         IT    4317    2/15/2020
# ..    ...                 ...  ...     ...        ...     ...          ...
# 995   996       Pamela Reeves   49  Female      Sales    7652    6/23/2024
# 996   997        Todd Johnson   29  Female      Sales    6754    7/20/2018
# 997   998     Michael Sanchez   18    Male      Sales    5278     7/5/2023
# 998   999       Ashley Taylor   51  Female         IT    5437    2/18/2022
# 999  1000         Shawn Scott   45    Male         IT    7364    7/31/2022
#
#      Performance Score  Experience    Status     Location  Session
# ...

# %%
# Confirming the number of rows and columns my data has
df.shape
# Out:
# (1000, 12)

# %% [markdown]
# ### The dataset has 1000 rows and 12 columns.

# %%
# Checking if there is a need for data cleaning

df.isnull().sum()
# Out:
# ID                     0
# Name                   0
# Age                    0
# Gender                 0
# Department             0
# Salary                 0
# Joining Date           0
# Performance Score    498
# Experience             0
# Status                 0
# Location               0
# Session                0
# dtype: int64

# %% [markdown]
# ### The Performance Score Column has 498 missing values while the rest are clean

# %%
# Checking if my data has duplicates

df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# ### There is no duplicate value in the dataset.

# %%
# Verifying the dataset type 
df.dtypes
# Out:
# ID                     int64
# Name                  object
# Age                    int64
# Gender                object
# Department            object
# Salary                 int64
# Joining Date          object
# Performance Score    float64
# Experience             int64
# Status                object
# Location              object
# Session               object
# dtype: object

# %% [markdown]
# ### The dataset contains object, float and integer.

# %%
df
# Out:
#        ID                Name  Age  Gender Department  Salary Joining Date  \
# 0       1        Cory Escobar   48  Female         HR    5641     5/3/2015
# 1       2     Timothy Sanchez   25   Other      Sales    4249    11/9/2020
# 2       3        Chad Nichols   57   Other      Sales    3058    2/12/2019
# 3       4  Christine Williams   58  Female         IT    5895     9/8/2017
# 4       5        Amber Harris   35   Other         IT    4317    2/15/2020
# ..    ...                 ...  ...     ...        ...     ...          ...
# 995   996       Pamela Reeves   49  Female      Sales    7652    6/23/2024
# 996   997        Todd Johnson   29  Female      Sales    6754    7/20/2018
# 997   998     Michael Sanchez   18    Male      Sales    5278     7/5/2023
# 998   999       Ashley Taylor   51  Female         IT    5437    2/18/2022
# 999  1000         Shawn Scott   45    Male         IT    7364    7/31/2022
#
#      Performance Score  Experience    Status     Location  Session
# ...

# %%
# Filling missing values

df_filled = df.fillna(df.mean(numeric_only = True))

df_filled
# Out:
#        ID                Name  Age  Gender Department  Salary Joining Date  \
# 0       1        Cory Escobar   48  Female         HR    5641     5/3/2015
# 1       2     Timothy Sanchez   25   Other      Sales    4249    11/9/2020
# 2       3        Chad Nichols   57   Other      Sales    3058    2/12/2019
# 3       4  Christine Williams   58  Female         IT    5895     9/8/2017
# 4       5        Amber Harris   35   Other         IT    4317    2/15/2020
# ..    ...                 ...  ...     ...        ...     ...          ...
# 995   996       Pamela Reeves   49  Female      Sales    7652    6/23/2024
# 996   997        Todd Johnson   29  Female      Sales    6754    7/20/2018
# 997   998     Michael Sanchez   18    Male      Sales    5278     7/5/2023
# 998   999       Ashley Taylor   51  Female         IT    5437    2/18/2022
# 999  1000         Shawn Scott   45    Male         IT    7364    7/31/2022
#
#      Performance Rating  Experience    Status     Location  Session
# ...

# %% [markdown]
# ### The Average(Mean) score in the Performance Score Column was used to fill the missing values.

# %%
# Filling missing values using the update method

df.update(df.fillna(df.mean(numeric_only =True)))
df
# Out:
#        ID                Name  Age  Gender Department  Salary Joining Date  \
# 0       1        Cory Escobar   48  Female         HR    5641     5/3/2015
# 1       2     Timothy Sanchez   25   Other      Sales    4249    11/9/2020
# 2       3        Chad Nichols   57   Other      Sales    3058    2/12/2019
# 3       4  Christine Williams   58  Female         IT    5895     9/8/2017
# 4       5        Amber Harris   35   Other         IT    4317    2/15/2020
# ..    ...                 ...  ...     ...        ...     ...          ...
# 995   996       Pamela Reeves   49  Female      Sales    7652    6/23/2024
# 996   997        Todd Johnson   29  Female      Sales    6754    7/20/2018
# 997   998     Michael Sanchez   18    Male      Sales    5278     7/5/2023
# 998   999       Ashley Taylor   51  Female         IT    5437    2/18/2022
# 999  1000         Shawn Scott   45    Male         IT    7364    7/31/2022
#
#      Performance Rating  Experience    Status     Location  Session
# ...

# %% [markdown]
# ## After filling the missing values using the initial method, I noticed that the original dataset was unable to modify. Therefore, the update () method was used as a result of not being able to modify the original dataset using inplace = True method because fillna() does not support inplace = True when passing Series like df.mean().

# %%
# Confirming if the dataset is thoroughly cleaned.

df.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Gender               0
# Department           0
# Salary               0
# Joining Date         0
# Performance Score    0
# Experience           0
# Status               0
# Location             0
# Session              0
# dtype: int64

# %% [markdown]
# ### The dataset is thoroughly cleaned and ready to be used for analysis.

# %%
# Counting the number of times each value appeared in the dataset using the value counts method.

df['Name'].value_counts()
# Out:
# Name
# Heather Jones       2
# Patricia Scott      2
# Larry Johnson       2
# Elizabeth Dudley    2
# Kimberly Burke      2
#                    ..
# Pamela Reeves       1
# Todd Johnson        1
# Michael Sanchez     1
# Ashley Taylor       1
# Shawn Scott         1
# Name: count, Length: 992, dtype: int64

# %% [markdown]
# ### Some names appeared twice but their variables are different hence it cant be said they are duplicates.

# %%
# Renaming of the 'Performance Score' column to 'Performance Rating' using the rename function.

df.rename(columns = {'Performance Score': 'Performance Rating'},inplace = True)
df
# Out:
#        ID                Name  Age  Gender Department  Salary Joining Date  \
# 0       1        Cory Escobar   48  Female         HR    5641     5/3/2015
# 1       2     Timothy Sanchez   25   Other      Sales    4249    11/9/2020
# 2       3        Chad Nichols   57   Other      Sales    3058    2/12/2019
# 3       4  Christine Williams   58  Female         IT    5895     9/8/2017
# 4       5        Amber Harris   35   Other         IT    4317    2/15/2020
# ..    ...                 ...  ...     ...        ...     ...          ...
# 995   996       Pamela Reeves   49  Female      Sales    7652    6/23/2024
# 996   997        Todd Johnson   29  Female      Sales    6754    7/20/2018
# 997   998     Michael Sanchez   18    Male      Sales    5278     7/5/2023
# 998   999       Ashley Taylor   51  Female         IT    5437    2/18/2022
# 999  1000         Shawn Scott   45    Male         IT    7364    7/31/2022
#
#      Performance Rating  Experience    Status     Location  Session
# ...

# %% [markdown]
# ### The Performance Score column was renamed to Performance Rating for a clearer understanding.

# %%
# Using the astype function to change the Performance Score Column from float to an integer.

df['Performance Rating'] = df['Performance Rating'].astype(int)
df
# Out:
#        ID                Name  Age  Gender Department  Salary Joining Date  \
# 0       1        Cory Escobar   48  Female         HR    5641     5/3/2015
# 1       2     Timothy Sanchez   25   Other      Sales    4249    11/9/2020
# 2       3        Chad Nichols   57   Other      Sales    3058    2/12/2019
# 3       4  Christine Williams   58  Female         IT    5895     9/8/2017
# 4       5        Amber Harris   35   Other         IT    4317    2/15/2020
# ..    ...                 ...  ...     ...        ...     ...          ...
# 995   996       Pamela Reeves   49  Female      Sales    7652    6/23/2024
# 996   997        Todd Johnson   29  Female      Sales    6754    7/20/2018
# 997   998     Michael Sanchez   18    Male      Sales    5278     7/5/2023
# 998   999       Ashley Taylor   51  Female         IT    5437    2/18/2022
# 999  1000         Shawn Scott   45    Male         IT    7364    7/31/2022
#
#      Performance Rating  Experience    Status     Location  Session
# ...

# %% [markdown]
# ### The Performance Rating values were converted from float to integer

# %%
# using the rename function to rename the Experience column.

df.rename(columns = {'Experience':'Years of Experience'}, inplace =True)
df
# Out:
#        ID                Name  Age  Gender Department  Salary Joining Date  \
# 0       1        Cory Escobar   48  Female         HR    5641     5/3/2015
# 1       2     Timothy Sanchez   25   Other      Sales    4249    11/9/2020
# 2       3        Chad Nichols   57   Other      Sales    3058    2/12/2019
# 3       4  Christine Williams   58  Female         IT    5895     9/8/2017
# 4       5        Amber Harris   35   Other         IT    4317    2/15/2020
# ..    ...                 ...  ...     ...        ...     ...          ...
# 995   996       Pamela Reeves   49  Female      Sales    7652    6/23/2024
# 996   997        Todd Johnson   29  Female      Sales    6754    7/20/2018
# 997   998     Michael Sanchez   18    Male      Sales    5278     7/5/2023
# 998   999       Ashley Taylor   51  Female         IT    5437    2/18/2022
# 999  1000         Shawn Scott   45    Male         IT    7364    7/31/2022
#
# ...

# %% [markdown]
# ### The Experience column was renamed to Years of Experience for professionalism.

# %%
df['Department'].value_counts()
# Out:
# Department
# IT       339
# Sales    338
# HR       323
# Name: count, dtype: int64

# %% [markdown]
# ### The IT department has the highest number of employees next to the Sales department while the Hr department has the least number of employees.

# %%
# filtering rows where the Age is not greater than 25 using the loc function.

df.loc[~(df['Age']>25)]
# Out:
#       ID             Name  Age  Gender Department  Salary Joining Date  \
# 1      2  Timothy Sanchez   25   Other      Sales    4249    11/9/2020
# 24    25    Tracy Carlson   21    Male         HR    9275     4/9/2022
# 26    27      Austin Long   20  Female         IT    4899     5/1/2024
# 29    30    Rachel Ramsey   22    Male      Sales    9661    8/18/2016
# 30    31     Brandi Smith   21   Other         IT    4780    1/20/2020
# ..   ...              ...  ...     ...        ...     ...          ...
# 989  990    Shannon Meyer   18   Other         HR    9985    11/5/2022
# 991  992  William Schultz   23   Other      Sales    4311    8/17/2019
# 992  993   Ashley Daniels   25   Other      Sales    5524   11/24/2022
# 994  995  Rachel Phillips   22    Male         IT    3096   10/27/2018
# 997  998  Michael Sanchez   18    Male      Sales    5278     7/5/2023
#
#      Performance Rating  Years of Experience    Status     Location  Session
# ...

# %% [markdown]
# ### The total number of 184 employees fell under the category of employees that their age is not greater than 25 years.

# %%
# filtering rows where the Age is 33 using the loc function.

df.loc[df['Age']==33]
# Out:
#       ID                 Name  Age  Gender Department  Salary Joining Date  \
# 38    39         Jordan Scott   33   Other      Sales    8678    5/15/2016
# 61    62        Carmen Taylor   33    Male      Sales    2851    1/30/2023
# 97    98       Matthew Fields   33  Female         HR    2378     8/7/2015
# 99   100      Thomas Hamilton   33    Male      Sales    8076   12/24/2017
# 134  135   Jonathan Schneider   33    Male      Sales    3843     8/3/2023
# 180  181     Sharon Patterson   33    Male         HR    6833     2/4/2015
# 234  235     Stuart Rodriguez   33   Other      Sales    7974    2/15/2017
# 240  241           Ashley Kim   33    Male         IT    2996   11/10/2023
# 309  310    Abigail Rodriguez   33  Female      Sales    3636    4/22/2017
# 313  314        Kenneth Brown   33    Male      Sales    4391     5/3/2020
# 384  385       Monica Baldwin   33  Female      Sales    7941    8/24/2017
# ...

# %% [markdown]
# ### We have 14 employees under the age of 33.

# %%
# Filtering rows where the Age is not less than 33 or the Department is IT

df.loc[~(df['Age']<33)|(df['Department']=='IT')]
# Out:
#        ID                Name  Age  Gender Department  Salary Joining Date  \
# 0       1        Cory Escobar   48  Female         HR    5641     5/3/2015
# 2       3        Chad Nichols   57   Other      Sales    3058    2/12/2019
# 3       4  Christine Williams   58  Female         IT    5895     9/8/2017
# 4       5        Amber Harris   35   Other         IT    4317    2/15/2020
# 6       7         David Olson   39  Female      Sales    6826    5/11/2023
# ..    ...                 ...  ...     ...        ...     ...          ...
# 990   991        Amy Johnston   53  Female         HR    3991     9/3/2024
# 994   995     Rachel Phillips   22    Male         IT    3096   10/27/2018
# 995   996       Pamela Reeves   49  Female      Sales    7652    6/23/2024
# 998   999       Ashley Taylor   51  Female         IT    5437    2/18/2022
# 999  1000         Shawn Scott   45    Male         IT    7364    7/31/2022
#
# ...

# %% [markdown]
# ### The total number of 774 employees fell under the category of employees where the Age is not less than 33 or the Department is IT in the dataset

# %%
# Filtering rows where the salary is 5,000 and the location is Chicago

df.loc[(df['Salary'] > 5000) & (df['Location']=='Chicago')]
# Out:
#       ID               Name  Age  Gender Department  Salary Joining Date  \
# 7      8       Amanda Baker   52   Other         HR    6285     4/1/2015
# 11    12  Rodney Richardson   60   Other         HR    6908    3/14/2015
# 12    13    Joshua Robinson   61    Male         IT    5688    6/21/2020
# 15    16        Gary Cooley   62    Male         HR    5386    7/25/2017
# 18    19     Nancy Stephens   38    Male         HR    9061    7/16/2017
# ..   ...                ...  ...     ...        ...     ...          ...
# 968  969   Nicholas Edwards   65   Other      Sales    8928     4/5/2020
# 971  972     Kelsey Fischer   22    Male         IT    9049    6/21/2016
# 983  984        David Moody   43    Male         HR    8830    9/10/2021
# 987  988     Danielle Brown   31  Female         IT    5605    6/28/2024
# 989  990      Shannon Meyer   18   Other         HR    9985    11/5/2022
#
#      Performance Rating  Years of Experience    Status Location  Session
# ...

# %% [markdown]
# ### 191 employees fell under the category of employees whose salaries are greater than 5,000 and their location is Chicago in the dataset.

# %%
# grouping of gender to get the minimum and maximum performance rating.

df.groupby('Gender')['Performance Rating'].agg(['min','max'])
# Out:
#         min  max
# Gender
# Female    1    5
# Male      1    5
# Other     1    5

# %% [markdown]
# ### The minimum performance rating of all employees irrespective of their is 1 while the maximum is 5 in the dataset.

# %%
# Grouping of dataframe by Gender and sum it with the Performance Rating

Gen_rating = df.groupby('Gender') ['Performance Rating'].sum().sort_values(ascending = False)
Gen_rating
# Out:
# Gender
# Female    852
# Other     822
# Male      783
# Name: Performance Rating, dtype: int64

# %% [markdown]
# ### The above analysis shows that the Female Gender has the highest performance rating and this could be because in most organization, females tend to be more jovial than the rest of the Genders.

# %%
# Calculating the number of each Status using the value_counts function

status_counts = df['Status'].value_counts()

status_counts
# Out:
# Status
# Active      501
# Inactive    499
# Name: count, dtype: int64

# %% [markdown]
# ### There are 499 inactive employees in the dataset and this could be due to some personal issues.

# %%
df[df['Status']=='Active']['Name']
# Out:
# 0         Cory Escobar
# 5          Ashley Howe
# 6          David Olson
# 9       Brian Faulkner
# 10         Nicole Bell
#             ...
# 989      Shannon Meyer
# 990       Amy Johnston
# 995      Pamela Reeves
# 997    Michael Sanchez
# 999        Shawn Scott
# Name: Name, Length: 501, dtype: object

# %% [markdown]
# ### The above analysis shows the names of all the active employees in the dataset.

# %%
# Filtering rows where the Names have Inactive Status

df[df['Status']=='Inactive']['Name']
# Out:
# 1         Timothy Sanchez
# 2            Chad Nichols
# 3      Christine Williams
# 4            Amber Harris
# 7            Amanda Baker
#               ...
# 992        Ashley Daniels
# 993         Brandon Bruce
# 994       Rachel Phillips
# 996          Todd Johnson
# 998         Ashley Taylor
# Name: Name, Length: 499, dtype: object

# %% [markdown]
# ### The above analysis shows the names of all the inactive employees in the dataset.

# %%
# Calculating the total number of each Gender

gender_count = df['Gender'].value_counts()

gender_count
# Out:
# Gender
# Other     340
# Female    332
# Male      328
# Name: count, dtype: int64

# %% [markdown]
# ### The Other Gender has the highest total number of employees in the dataset.

# %%
# Total Number of employees working in each session

session_counts = df['Session'].value_counts()

session_counts
# Out:
# Session
# Night      340
# Morning    334
# Evening    326
# Name: count, dtype: int64

# %% [markdown]
# ### The dataset is made up of 3 sessions, Morning, Evening and Night and the Night session has the highest number of employees.

# %%
# Filtering the Names of Employees on Morning Session

df[df['Session']=='Morning']['Name']
# Out:
# 2            Chad Nichols
# 9          Brian Faulkner
# 15            Gary Cooley
# 17     Jacqueline Randall
# 24          Tracy Carlson
#               ...
# 990          Amy Johnston
# 992        Ashley Daniels
# 996          Todd Johnson
# 997       Michael Sanchez
# 999           Shawn Scott
# Name: Name, Length: 334, dtype: object

# %% [markdown]
# ### The Morning Session has a total number of 334 employees and their names are displayed above respectively.

# %%
# Filtering Names of Employees on Evening Session

df[df['Session']=='Evening']['Name']
# Out:
# 1         Timothy Sanchez
# 3      Christine Williams
# 4            Amber Harris
# 5             Ashley Howe
# 7            Amanda Baker
#               ...
# 983           David Moody
# 991       William Schultz
# 994       Rachel Phillips
# 995         Pamela Reeves
# 998         Ashley Taylor
# Name: Name, Length: 326, dtype: object

# %% [markdown]
# ### The Evening Session has a total number 326 employees and their respective names are displayed above.

# %%
# Filtering Names of Employees on Night Session

df[df['Session']=='Night']['Name']
# Out:
# 0           Cory Escobar
# 6            David Olson
# 8          Jeremy Wright
# 11     Rodney Richardson
# 12       Joshua Robinson
#              ...
# 980      Jeffrey Johnson
# 984         Jeffrey Hall
# 988       Hannah Hickman
# 989        Shannon Meyer
# 993        Brandon Bruce
# Name: Name, Length: 340, dtype: object

# %% [markdown]
# ### The Night Session has a total number of 340 employees and their individual names are displayed above.

# %%
# Total Number of employees working in each Location

location_counts = df['Location'].value_counts()

location_counts
# Out:
# Location
# Los Angeles    335
# Chicago        333
# New York       332
# Name: count, dtype: int64

# %% [markdown]
# ### The dataset has 3 locations, and Los Angeles has the highest number of employees.

# %%
# Filtering rows where employees are in Los Angeles

df[df['Location'] == 'Los Angeles']['Name']
# Out:
# 1         Timothy Sanchez
# 3      Christine Williams
# 9          Brian Faulkner
# 10            Nicole Bell
# 13      Benjamin Callahan
#               ...
# 984          Jeffrey Hall
# 985       Regina Ferguson
# 991       William Schultz
# 995         Pamela Reeves
# 998         Ashley Taylor
# Name: Name, Length: 335, dtype: object

# %% [markdown]
# ### The above analysis shows the names of all the employees that their location is in Los Angeles in the dataset.

# %%
# Filtering rows where Employees are in Chicago.

df[df['Location'] == 'Chicago']['Name']
# Out:
# 5            Ashley Howe
# 7           Amanda Baker
# 11     Rodney Richardson
# 12       Joshua Robinson
# 15           Gary Cooley
#              ...
# 987       Danielle Brown
# 989        Shannon Meyer
# 990         Amy Johnston
# 993        Brandon Bruce
# 994      Rachel Phillips
# Name: Name, Length: 333, dtype: object

# %% [markdown]
# ### The above analysis displays the names of all the employees in the dataset whose location is in Chicago.

# %%
# Filtering rows where Employees are in New York

df[df['Location'] == 'New York']['Name']
# Out:
# 0         Cory Escobar
# 2         Chad Nichols
# 4         Amber Harris
# 6          David Olson
# 8        Jeremy Wright
#             ...
# 988     Hannah Hickman
# 992     Ashley Daniels
# 996       Todd Johnson
# 997    Michael Sanchez
# 999        Shawn Scott
# Name: Name, Length: 332, dtype: object

# %% [markdown]
# ### The above names are the names of employees whose location is in New York.

# %%
# Retrieving an employee details by their respective names using the loc function

def get_employee_info(name):
    employee_info =df.loc[df['Name'] == name]
    if not employee_info.empty:
        return employee_info
    else:
        return f"Employee'{name}' not found in the dataset"
        return f"An error occurred:{e}"
employee_name ='Adam Thomas'
result = get_employee_info(employee_name)

result
# Out:
#       ID         Name  Age  Gender Department  Salary Joining Date  \
# 566  567  Adam Thomas   32  Female         HR    9370     5/8/2021
#
#      Performance Rating  Years of Experience    Status  Location Session
# 566                   4                   20  Inactive  New York   Night

# %% [markdown]
# ### The above analysis illustrates how a certain employee's details/information can be retrieved using the loc function.

# %%
#  Calculating employees' average salary and their performance rating.

pivot = df.pivot_table(index = "Name", values =["Salary", "Performance Rating"], aggfunc = "mean")
pivot
# Out:
#                    Performance Rating  Salary
# Name
# Abigail Rodriguez                 4.0  3636.0
# Adam Lane                         1.0  7485.0
# Adam Thomas                       4.0  9370.0
# Albert Stevens                    2.0  2776.0
# Alejandro Bennett                 2.0  7039.0
# ...                               ...     ...
# Zachary Bowen                     2.0  2712.0
# Zachary Brown                     2.0  4750.0
# Zachary Cox                       2.0  2499.0
# Zachary Gutierrez                 2.0  3491.0
# Zoe Camacho                       4.0  2451.0
#
# [992 rows x 2 columns]

# %%
# Sorting top10 employees average salary

top_10 = pivot.sort_values(by  ="Performance Rating", ascending = False).head(10)
top_10
# Out:
#                   Performance Rating  Salary
# Name
# Wendy Taylor                     5.0  7632.0
# Veronica Bennett                 5.0  5497.0
# Amber Rodriguez                  5.0  4941.0
# Amber Harris                     5.0  4317.0
# Tammy Smith                      5.0  2087.0
# Tara Mccoy                       5.0  8103.0
# Tara Blackwell                   5.0  6120.0
# Taylor Griffin                   5.0  5721.0
# Taylor Dean                      5.0  4424.0
# Steve Morton                     5.0  3265.0

# %%
top_10.plot(kind = "bar", color = 'gray', figsize =(12,6))
plt.title("Top 10 Employees by Average Salary and Performance Rating")
plt.ylabel("Salary")
plt.xlabel("Employee Names")
plt.xticks()
plt.legend(["Average Salary", "Average Performance Rating"])
plt.grid(axis ="y", linestyle = "--", alpha = 0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The above chart shows that Tammy Smith has the least average salary while Tara Mccoy has the highest average salary amongst the top 10 most paid employee, the reason could be due to their years of experiece and or their Departments.

# %%
# Calculating the average Salaries by Department using the group by method

dept =df.groupby('Department')['Salary'].mean()

dept
# Out:
# Department
# HR       5982.396285
# IT       5968.371681
# Sales    5804.088757
# Name: Salary, dtype: float64

# %%
plt.plot(dept, marker= 'o')
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.title("Employees' average salary by Department")
plt.show()

# %% [markdown]
# ### The above chart shows the average salary by department and the sales department has the lowest average salary while the Hr department has the highest average salary, the reason could be that the sales department are paid based on their monthly sales performance.

# %%
top10_oldest = df.sort_values(by ="Years of Experience", ascending =False).head(10)
top10_oldest
# Out:
#       ID            Name  Age  Gender Department  Salary Joining Date  \
# 396  397  Carolyn Arnold   37    Male         HR    8104   11/24/2020
# 402  403   Briana Martin   59    Male      Sales    4496    5/22/2023
# 640  641     Laurie Mata   51   Other         HR    3779   11/27/2021
# 612  613    Kelsey Hines   64   Other         IT    9282    10/6/2016
# 765  766     Steve Smith   42  Female      Sales    3414    2/13/2023
# 387  388     Corey Smith   27   Other      Sales    2593    7/27/2017
# 764  765    Roberta Haas   48    Male         HR    3927    7/13/2019
# 330  331       Juan Dean   39    Male         HR    6830    6/28/2015
# 355  356  Laura Castillo   41    Male         IT    2392    3/15/2024
# 429  430  Matthew Turner   62  Female         IT    4753    6/13/2020
#
#      Performance Rating  Years of Experience    Status     Location  Session
# 396                   2                   20    Active  Los Angeles  Morning
# ...

# %%
pivot_table  =top10_oldest.pivot_table(index = "Name",  values =[ "Salary", "Years of Experience"], aggfunc="max")

pivot_table
# Out:
#                 Salary  Years of Experience
# Name
# Briana Martin     4496                   20
# Carolyn Arnold    8104                   20
# Corey Smith       2593                   20
# Juan Dean         6830                   20
# Kelsey Hines      9282                   20
# Laura Castillo    2392                   20
# Laurie Mata       3779                   20
# Matthew Turner    4753                   20
# Roberta Haas      3927                   20
# Steve Smith       3414                   20

# %%
plt.figure(figsize =(12,8))
sns.heatmap(pivot_table, annot =True,fmt = ".0f", cmap = "YlGnBu", linewidths = 0.5,)
plt.title ("Top 10 oldest Employees by Years of Experience", fontsize = 16)
plt.xlabel ("Years of Experience", fontsize = 12)
plt.ylabel ("Name", fontsize = 12)
plt.show()

# %% [markdown]
# ### The above heatmap chart shows that all the oldest top10 employees have the same years of experience but different ranges of salary this could be because of their respective departments.

# %%
# Average Salary by Gender

Gender_sal = df.groupby('Gender')['Salary'].mean()
Gender_sal
# Out:
# Gender
# Female    5793.078313
# Male      6090.862805
# Other     5871.379412
# Name: Salary, dtype: float64

# %%
plt.figure(figsize = (8,8))
plt.pie(Gender_sal, labels = ['Female', 'Male', 'Other'], autopct ='%1.1f%%', startangle =90, colors = ['brown', 'gold', 'gray'])
plt.title("Highest paid Gender")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### The above pie chart shows that the male Gender has the highest paid salary. The reason could be that the male gender occupies higher positions with higher pay more than the Other and the Female genders.
